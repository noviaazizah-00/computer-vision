# %%
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
cv2.__file__
# Out:
# 'C:\\Users\\user\\anaconda3\\envs\\ENV_Kelompok3\\lib\\site-packages\\cv2\\__init__.py'

# %%
img = cv2.imread("bunga.jpg.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape # h, w, c
# Out:
# (467, 350, 3)

# %%
type(img.shape)
# Out:
# tuple

# %%
# tuple unpacking
h, w, c = img.shape

# %%
h, w, c
# Out:
# (467, 350, 3)

# %%
h*w
# Out:
# 163450

# %%
img.nbytes
# Out:
# 490350

# %%
img.nbytes/1024
# Out:
# 478.857421875

# %%
import os

# %%
os.path.getsize("bunga.jpg.jpg")/1024
# Out:
# 53.5380859375

# %%
img.ndim #30
# Out:
# 3

# %%
img.min()
# Out:
# np.uint8(0)

# %%
img.max()
# Out:
# np.uint8(255)

# %%
img.size # n pixel
# Out:
# 490350

# %%
h*w*c # n pixel
# Out:
# 490350

# %%
img.shape
# Out:
# (467, 350, 3)

# %%
img[:, :, 0].shape # layer 0 (Blue)
# Out:
# (467, 350)

# %%
img[:, :, 1].shape # layer 1 (Green)
# Out:
# (467, 350)

# %%
img[:, :, 2].shape # layer 2 (Red)
# Out:
# (467, 350)
